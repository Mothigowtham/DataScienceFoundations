# %% [markdown]
# #**NIFTY case-study**

# %%
import pandas as pd
import numpy as np

# %%
# !head 'NIFTY.csv'
# Out:
# Date,Close
# 01-Jan-2019,10910.10
# 02-Jan-2019,10792.50
# 03-Jan-2019,10672.25
# 04-Jan-2019,10727.35
# 07-Jan-2019,10771.80
# 08-Jan-2019,10802.15
# 09-Jan-2019,10855.15
# 10-Jan-2019,10821.60
# 11-Jan-2019,10794.95

# %%
nifty = pd.read_csv('NIFTY.csv', index_col= 0 )

# %%
nifty
# Out:
#                 Close
# Date
# 01-Jan-2019  10910.10
# 02-Jan-2019  10792.50
# 03-Jan-2019  10672.25
# 04-Jan-2019  10727.35
# 07-Jan-2019  10771.80
# ...               ...
# 24-Dec-2019  12214.55
# 26-Dec-2019  12126.55
# 27-Dec-2019  12245.80
# 30-Dec-2019  12255.85
# 31-Dec-2019  12168.45
#
# [245 rows x 1 columns]

# %%
nifty = pd.read_csv('9.1 - NIFTY.csv', index_col= 0 ).iloc[:, 0]

# %%
nifty
# Out:
# Date
# 01-Jan-2019    10910.10
# 02-Jan-2019    10792.50
# 03-Jan-2019    10672.25
# 04-Jan-2019    10727.35
# 07-Jan-2019    10771.80
#                  ...
# 24-Dec-2019    12214.55
# 26-Dec-2019    12126.55
# 27-Dec-2019    12245.80
# 30-Dec-2019    12255.85
# 31-Dec-2019    12168.45
# Name: Close, Length: 245, dtype: float64

# %%
nifty.head(25)
# Out:
# Date
# 01-Jan-2019    10910.10
# 02-Jan-2019    10792.50
# 03-Jan-2019    10672.25
# 04-Jan-2019    10727.35
# 07-Jan-2019    10771.80
# 08-Jan-2019    10802.15
# 09-Jan-2019    10855.15
# 10-Jan-2019    10821.60
# 11-Jan-2019    10794.95
# 14-Jan-2019    10737.60
# 15-Jan-2019    10886.80
# 16-Jan-2019    10890.30
# 17-Jan-2019    10905.20
# 18-Jan-2019    10906.95
# 21-Jan-2019    10961.85
# 22-Jan-2019    10922.75
# 23-Jan-2019    10831.50
# 24-Jan-2019    10849.80
# 25-Jan-2019    10780.55
# 28-Jan-2019    10661.55
# 29-Jan-2019    10652.20
# 30-Jan-2019    10651.80
# 31-Jan-2019    10830.95
# 01-Feb-2019    10893.65
# 04-Feb-2019    10912.25
# Name: Close, dtype: float64

# %%
nifty.tail(25)
# Out:
# Date
# 26-Nov-2019    12037.70
# 27-Nov-2019    12100.70
# 28-Nov-2019    12151.15
# 29-Nov-2019    12056.05
# 02-Dec-2019    12048.20
# 03-Dec-2019    11994.20
# 04-Dec-2019    12043.20
# 05-Dec-2019    12018.40
# 06-Dec-2019    11921.50
# 09-Dec-2019    11937.50
# 10-Dec-2019    11856.80
# 11-Dec-2019    11910.15
# 12-Dec-2019    11971.80
# 13-Dec-2019    12086.70
# 16-Dec-2019    12053.95
# 17-Dec-2019    12165.00
# 18-Dec-2019    12221.65
# 19-Dec-2019    12259.70
# 20-Dec-2019    12271.80
# 23-Dec-2019    12262.75
# 24-Dec-2019    12214.55
# 26-Dec-2019    12126.55
# 27-Dec-2019    12245.80
# 30-Dec-2019    12255.85
# 31-Dec-2019    12168.45
# Name: Close, dtype: float64

# %%
nifty.mean()
# Out:
# 11432.632244897959

# %%
nifty.median()
# Out:
# 11512.4

# %%
nifty.std()
# Out:
# 454.2146111618279

# %%
nifty.var()
# Out:
# 206310.91299289055

# %%
np.mean(nifty)
# Out:
# 11432.632244897959

# %%
nifty.sum()
# Out:
# 2800994.9

# %%
nifty.describe()
# Out:
# count      245.000000
# mean     11432.632245
# std        454.214611
# min      10604.350000
# 25%      11003.050000
# 50%      11512.400000
# 75%      11841.550000
# max      12271.800000
# Name: Close, dtype: float64

# %% [markdown]
# ## **Task**
#
# 1. <font color = 'Green'>**What fraction of the days did the markets close higher than the previous days.**

# %% [markdown]
# ## **Problem 1**

# %%
len(nifty)
# Out:
# 245

# %%
nifty.values[1:] - nifty.values[:-1]
# Out:
# array([-1.1760e+02, -1.2025e+02,  5.5100e+01,  4.4450e+01,  3.0350e+01,
#         5.3000e+01, -3.3550e+01, -2.6650e+01, -5.7350e+01,  1.4920e+02,
#         3.5000e+00,  1.4900e+01,  1.7500e+00,  5.4900e+01, -3.9100e+01,
#        -9.1250e+01,  1.8300e+01, -6.9250e+01, -1.1900e+02, -9.3500e+00,
#        -4.0000e-01,  1.7915e+02,  6.2700e+01,  1.8600e+01,  2.2100e+01,
#         1.2810e+02,  6.9500e+00, -1.2580e+02, -5.4800e+01, -5.7400e+01,
#        -3.7750e+01, -4.7600e+01, -2.1650e+01, -8.3450e+01, -3.6600e+01,
#         1.3110e+02,  5.4400e+01,  1.8000e+00,  8.8450e+01, -4.4800e+01,
#        -2.8650e+01, -1.4150e+01,  7.1000e+01,  1.2395e+02,  6.5550e+01,
#         5.2000e+00, -2.2800e+01,  1.3265e+02,  1.3315e+02,  4.0500e+01,
#         1.5500e+00,  8.3600e+01,  3.5350e+01,  7.0200e+01, -1.1350e+01,
#        -6.4150e+01, -1.0265e+02,  1.2900e+02, -3.8200e+01,  1.2495e+02,
#         5.3900e+01,  4.5250e+01,  4.4050e+01, -6.9250e+01, -4.5950e+01,
# ...

# %%
np.sum(nifty.values[1:] - nifty.values[:-1] > 0)
# Out:
# 129

# %%
np.sum(nifty.values[1:] - nifty.values[:-1] > 0)/len(nifty)
# Out:
# 0.5265306122448979

# %% [markdown]
# ***Here, we could conclude that more than half of the year markets close is higher than the previous days close.***

# %% [markdown]
# ## **Tasks**
#
# 2. <font color = 'Green'>**Compute the moving average of the last 5 days.**
# 3. <font color = 'Green'>**Subset the data to include only data for Fridays.**

# %% [markdown]
# ## **Problem 2**

# %%
pd.notna(nifty)
# Out:
# Date
# 01-Jan-2019    True
# 02-Jan-2019    True
# 03-Jan-2019    True
# 04-Jan-2019    True
# 07-Jan-2019    True
#                ...
# 24-Dec-2019    True
# 26-Dec-2019    True
# 27-Dec-2019    True
# 30-Dec-2019    True
# 31-Dec-2019    True
# Name: Close, Length: 245, dtype: bool

# %%
nifty.index[0]
# Out:
# '01-Jan-2019'

# %%
pd.Timestamp(nifty.index[0])
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.Timestamp(nifty.index[0]).dayofweek
# Out:
# 1

# %%
new_index = map(pd.Timestamp, nifty.index)

# %%
new_nifty = pd.Series(nifty, index = new_index)

# %%
new_nifty.index[0]
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
new_nifty.rolling('5d').mean()
# Out:
# 2019-01-01    10910.100000
# 2019-01-02    10851.300000
# 2019-01-03    10791.616667
# 2019-01-04    10775.550000
# 2019-01-07    10723.800000
#                   ...
# 2019-12-24    12249.700000
# 2019-12-26    12201.283333
# 2019-12-27    12212.412500
# 2019-12-30    12209.400000
# 2019-12-31    12223.366667
# Name: Close, Length: 245, dtype: float64

# %%
new_nifty_rolling = new_nifty.rolling('5d').mean()

# %%
new_nifty_rolling.plot();

# %%
nifty.plot();

# %% [markdown]
# ***The above graphs clearly compares the moving averages of the 5d with the original moving average.***

# %% [markdown]
# ## **Problem 3**

# %%
dow = new_nifty.copy()

# %%
for i in dow.index:
    dow[i] = i.dayofweek

# %%
friday_subset = new_nifty[dow == 4]

# %%
friday_subset
# Out:
# 2019-01-04    10727.35
# 2019-01-11    10794.95
# 2019-01-18    10906.95
# 2019-01-25    10780.55
# 2019-02-01    10893.65
# 2019-02-08    10943.60
# 2019-02-15    10724.40
# 2019-02-22    10791.65
# 2019-03-01    10863.50
# 2019-03-08    11035.40
# 2019-03-15    11426.85
# 2019-03-22    11456.90
# 2019-03-29    11623.90
# 2019-04-05    11665.95
# 2019-04-12    11643.45
# 2019-04-26    11754.65
# 2019-05-03    11712.25
# 2019-05-10    11278.90
# 2019-05-17    11407.15
# 2019-05-24    11844.10
# 2019-05-31    11922.80
# 2019-06-07    11870.65
# 2019-06-14    11823.30
# 2019-06-21    11724.10
# 2019-06-28    11788.85
# 2019-07-05    11811.15
# 2019-07-12    11552.50
# 2019-07-19    11419.25
# 2019-07-26    11284.30
# 2019-08-02    10997.35
# 2019-08-09    11109.65
# 2019-08-16    11047.80
# 2019-08-23    10829.35
# 2019-08-30    11023.25
# 2019-09-06    10946.20
# 2019-09-13    11075.90
# 2019-09-20    11274.20
# 2019-09-27    11512.40
# 2019-10-04    11174.75
# 2019-10-11    11305.05
# ...

# %% [markdown]
# ***We can now able to see the subset containing the market values of all fridays in the year.***
